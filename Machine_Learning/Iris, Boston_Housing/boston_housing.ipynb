# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"

raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
x = data

# %%
y = target

# %%
x.shape
# Out:
# (506, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
len(x_train), len(x_test)
# Out:
# (404, 102)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(128, input_dim = 13, activation = 'relu')) # x_train.shape
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(1, activation = 'linear')) # y_train.shape

# %%
# model.summary()

# %%
model.compile(optimizer = 'adam', loss = 'mse', metrics=['mae'])

# %%
model.fit(x_train, y_train, epochs = 200, batch_size = 32, verbose = 2)
# Out:
# Epoch 1/200
# 13/13 - 1s - loss: 562.5630 - mae: 18.3048 - 1s/epoch - 111ms/step
# Epoch 2/200
# 13/13 - 0s - loss: 109.7611 - mae: 7.6018 - 41ms/epoch - 3ms/step
# Epoch 3/200
# 13/13 - 0s - loss: 76.7441 - mae: 6.5752 - 39ms/epoch - 3ms/step
# Epoch 4/200
# 13/13 - 0s - loss: 68.4925 - mae: 5.8444 - 39ms/epoch - 3ms/step
# Epoch 5/200
# 13/13 - 0s - loss: 65.5646 - mae: 5.9382 - 40ms/epoch - 3ms/step
# Epoch 6/200
# 13/13 - 0s - loss: 64.1731 - mae: 5.7334 - 41ms/epoch - 3ms/step
# Epoch 7/200
# 13/13 - 0s - loss: 63.6413 - mae: 5.5827 - 39ms/epoch - 3ms/step
# Epoch 8/200
# 13/13 - 0s - loss: 63.4723 - mae: 5.7281 - 42ms/epoch - 3ms/step
# Epoch 9/200
# 13/13 - 0s - loss: 62.4844 - mae: 5.6365 - 45ms/epoch - 3ms/step
# Epoch 10/200
# 13/13 - 0s - loss: 61.9577 - mae: 5.5888 - 41ms/epoch - 3ms/step
# Epoch 11/200
# 13/13 - 0s - loss: 61.3250 - mae: 5.5862 - 38ms/epoch - 3ms/step
# Epoch 12/200
# 13/13 - 0s - loss: 60.7690 - mae: 5.5507 - 36ms/epoch - 3ms/step
# Epoch 13/200
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 11.5813 - mae: 2.6351
# [11.581320762634277, 2.635112762451172]

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
y_pred[0]
# Out:
# array([17.165955], dtype=float32)

# %%
y_test[0]
# Out:
# 13.1

# %%
from sklearn.metrics import accuracy_score

# %%
x_test1 = np.reshape(x_test[0], (1, 13))

# %%
model.predict(x_test1)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[17.16595]], dtype=float32)
