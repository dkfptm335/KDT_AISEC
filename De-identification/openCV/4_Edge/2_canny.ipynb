# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import Image
from IPython.core.display import HTML

Image(url="https://docs.opencv.org/4.5.2/nms.jpg")
# Out:
# <img src="https://docs.opencv.org/4.5.2/nms.jpg"/>

# %%
fig = plt.figure(figsize=(15, 15))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

img = cv.imread('../samples/messi5.jpg', 0)
edge1 = cv.Canny(img, 100, 200)
edge2 = cv.Canny(img, 100, 200, L2gradient=True)

ax1.imshow(img, cmap='gray')
ax2.imshow(edge1, cmap='gray')
ax3.imshow(edge2, cmap='gray')
